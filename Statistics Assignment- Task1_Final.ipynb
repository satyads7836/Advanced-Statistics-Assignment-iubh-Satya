# %% [markdown]
# Task 1: Basic Probabilities and Visualizations
# Please provide the requested visualization as well as the numerical results. In both cases, please either prove or
# cite any computation of the proof steps (calculations, code, steps, etc.), and justify why you trust the tools you
# used. Do not forget to include the scale of each graphics so that the reader can interpret the numbers represented.
# As indicated in the remark above, only perform one of the following tasks based on your personal value of 𝜉1:
# If 𝜉1 is 0: A vote with the outcome 𝑓𝑜𝑟 or 𝑎𝑔𝑎𝑖𝑛𝑠𝑡 follows a Bernoulli distribution where 𝑃(vote =
# "𝑓𝑜𝑟") = 𝜉2.
# Represent the proportion of “for” and “against” in this single Bernoulli trial using a graphic and a percentage. Can
# an expectation be calculated? Justify your answer with all necessary hypotheses.
# If 𝜉1 is between 1 and 3:
# The number of meteorites falling into an ocean in a given year can be modeled by one of the following
# distributions. Provide a graphic showing the probability of one, two, three, etc., meteorites falling (until the
# probability remains less than 0.5% for any higher number of meteorites; you should also prove it). Calculate the
# expectation and median and present them in this graphic:
# • If 𝜉1 is 1: a Poisson distribution with an expectation of 𝜆 = 𝜉2
# • If 𝜉1 is 2: a negative binomial distribution with an expectation of 𝑘 = 𝜉2 and 𝑝 = 𝜉3
# • If 𝜉1 is 3: a geometric distribution counting the number of Bernoulli trials with 𝑝 = 𝜉2 until it succeeds.

# %% [markdown]
# We are considering the values as 𝜉1 = 2, 𝜉2 = 2 and 𝜉3 = 3, therefore we are able to go ahead with negative binomial distribution.
#
# The negative binomial distribution models the number of failures before a specified number of successes is reached.
#
# For this case, we have that expectation of 𝑘=𝜉2=2 and 𝑝=𝜉3=3.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import nbinom

k = 2  # expectation
p = 1/3  # success probability in each trial

# Generate a range of meteorites (failures before k successes)
meteorites = np.arange(0, 20)

# Calculate the corresponding probabilities
probabilities = nbinom.pmf(meteorites, k, p)

# Calculate the expectation and median
expectation = nbinom.mean(k, p)
median = nbinom.median(k, p)

# Create the plot
plt.figure(figsize=(10, 6))
plt.bar(meteorites, probabilities)
plt.xlabel('Number of meteorites')
plt.ylabel('Probability')
plt.title('Negative Binomial Distribution')
plt.axvline(expectation, color='r', linestyle='dashed', linewidth=1, label=f'Expectation: {expectation:.2f}')
plt.axvline(median, color='g', linestyle='dashed', linewidth=1, label=f'Median: {median:.2f}')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# The negative binomial distribution is used to model the number of failures before a specified number of successes occur. In my  case, the expectation of 𝑘 = 𝜉2 = 2 and 𝑝 = 𝜉3 = 1/3.
# The probability mass function (PMF) of a negative binomial distribution is given by:
# P(X=x)=C(x+k−1,k−1)∗pk∗(1−p)x
# where:
#
# X is the number of failures before the kth success,
# C(n, r) is the binomial coefficient which can be calculated as n! / [r!(n - r)!],
# p is the probability of success in each trial,
# k is the number of successes.
#
# we want to calculate the probability of x failures before 2 successes occur, with a success probability of 1/3. So, the PMF becomes:
# P(X=x)=C(x+2−1,2−1)∗(1/3)2∗(1−1/3)x
# The expectation (mean) of a negative binomial distribution is given by:
# E[X]=k∗(1−p)/p
# So, the expectation in your case is:
# E[X]=2∗(1−1/3)/(1/3)=4
# The median of a negative binomial distribution doesn’t have a simple closed form and is usually computed numerically.
# However, for large k, it is approximately equal to k * (1 - p) / p, which is the same as the expectation.

# %% [markdown]
# Mathematical derivation for different value of 𝜉1:
#
# 1. If 𝜉1 is 0:
#    The vote with the outcome "for" or "against" follows a Bernoulli distribution where 𝑃(vote = "for") = 𝜉2. The Bernoulli distribution is a discrete probability distribution for a random variable which takes a binary, boolean output: 1 (for success) with probability 𝑝 = 𝜉2 and 0 (for failure) with probability 𝑞 = 1 - 𝜉2.
#
#    The probability mass function (PMF) of a Bernoulli distribution is given by:
#
#    $$ P(X = x) = p^x * (1 - p)^{1 - x} $$
#
#    for x in {0, 1}. Here, X is a random variable representing the outcome of a single Bernoulli trial (1 for "for", 0 for "against").
#
#    The expectation (mean) of a Bernoulli distribution is 𝑝, and the variance is 𝑝 * (1 - 𝑝).
#
# 2. If 𝜉1 is between 1 and 3:
#    The number of meteorites falling into an ocean in a given year can be modeled by one of the following distributions:
#
#    - If 𝜉1 is 1: A Poisson distribution with an expectation of 𝜆 = 𝜉2. The Poisson distribution models the number of events happening in a fixed interval of time or space. The PMF of a Poisson distribution is given by:
#
#      $$ P(X = x) = e^{-λ} * λ^x / x! $$
#
#      for x = 0, 1, 2, ..., where X is the number of events (meteorites), λ is the average rate of events (𝜉2), and e is the base of the natural logarithm.
#
#      The expectation (mean) and variance of a Poisson distribution are both 𝜆.
#
#    - If 𝜉1 is 2:A negative binomial distribution with an expectation of 𝑘 = 𝜉2 and 𝑝 = 𝜉3. The negative binomial distribution models the number of failures before a specified number of successes occur. The PMF of a negative binomial distribution is given by:
#
#      $$ P(X = x) = C(x + k - 1, k - 1) * p^k * (1 - p)^x $$
#
#      where X is the number of failures before the kth success, C(n, r) is the binomial coefficient, p is the probability of success in each trial, and k is the number of successes.
#
#      The expectation (mean) of a negative binomial distribution is 𝑘 * (1 - 𝑝) / 𝑝, and the variance is 𝑘 * (1 - 𝑝) / 𝑝^2.
#
#    - If 𝜉1 is 3: A geometric distribution counting the number of Bernoulli trials with 𝑝 = 𝜉2 until it succeeds. The geometric distribution models the number of trials needed to get the first success in repeated Bernoulli trials. The PMF of a geometric distribution is given by:
#
#      $$ P(X = x) = (1 - p)^{x - 1} * p $$
#
#      for x = 1, 2, 3, ..., where X is the number of trials until the first success, and p is the probability of success on each trial.
#
#      The expectation (mean) of a geometric distribution is 1 / 𝑝, and the variance is (1 - 𝑝) / 𝑝^2.

# %% [markdown]
# If 𝜉1 is 0: Here’s the Python code for a Bernoulli distribution where 𝑃(vote = “for”) = 𝜉2

# %%
import matplotlib.pyplot as plt
from scipy.stats import bernoulli

p = 0.5  # probability of vote = "for"

# Generate a range of votes (0 for "against", 1 for "for")
votes = [0, 1]

# Calculate the corresponding probabilities
probabilities = bernoulli.pmf(votes, p)

# Create the plot
plt.bar(votes, probabilities, tick_label=['against', 'for'])
plt.xlabel('Vote')
plt.ylabel('Probability')
plt.title('Bernoulli Distribution of Votes')
plt.show()

# %% [markdown]
# If 𝜉1 is between 1 and 3:
# If 𝜉1 is 1: Python code for a Poisson distribution with an expectation of 𝜆 = 𝜉2.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson

lambda_ = 2  # average rate of events

# Generate a range of meteorites (number of events)
meteorites = np.arange(0, 10)

# Calculate the corresponding probabilities
probabilities = poisson.pmf(meteorites, lambda_)

# Create the plot
plt.bar(meteorites, probabilities)
plt.xlabel('Number of meteorites')
plt.ylabel('Probability')
plt.title('Poisson Distribution of Meteorites')
plt.show()

# %% [markdown]
# If 𝜉1 is 2: Python code for a negative binomial distribution with an expectation of 𝑘 = 𝜉2 and 𝑝 = 𝜉3.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import nbinom

k = 2  # number of successes
p = 0.5  # probability of success in each trial

# Generate a range of meteorites (failures before k successes)
meteorites = np.arange(0, 10)

# Calculate the corresponding probabilities
probabilities = nbinom.pmf(meteorites, k, p)

# Create the plot
plt.bar(meteorites, probabilities)
plt.xlabel('Number of meteorites')
plt.ylabel('Probability')
plt.title('Negative Binomial Distribution of Meteorites')
plt.show()

# %% [markdown]
# If 𝜉1 is 3: Python code for a geometric distribution counting the number of Bernoulli trials with 𝑝 = 𝜉2 until it succeeds.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import geom
p = 0.5  # probability of success on each trial

# Generate a range of trials until the first success
trials = np.arange(1, 10)

# Calculate the corresponding probabilities
probabilities = geom.pmf(trials, p)

# Create the plot
plt.bar(trials, probabilities)
plt.xlabel('Number of trials')
plt.ylabel('Probability')
plt.title('Geometric Distribution of Trials')
plt.show()

# %% [markdown]
# References for Above solution:
# Bernoulli Distribution:
# Mathematical Derivation: “Bernoulli Distribution” - Wikipedia
# Python Code: “Bernoulli Distribution” - SciPy Documentation
# Poisson Distribution:
# Mathematical Derivation: “Poisson Distribution” - Wikipedia
# Python Code: “Poisson Distribution” - SciPy Documentation
# Negative Binomial Distribution:
# Mathematical Derivation: “Negative Binomial Distribution” - Wikipedia
# Python Code: “Negative Binomial Distribution” - SciPy Documentation
# Geometric Distribution:
# Mathematical Derivation: “Geometric Distribution” - Wikipedia
# Python Code: “Geometric Distribution” - SciPy Documentation
